# %%
from the_quiver import *

OdsumN(3)

def f(x):
    return x -2

Bisection(1,6,0.00001,f)

A = identity_matx(3)
B = identity_matx(3)
prod_matx(A,B)
disp_matx(add_matx(A,B))
# Out:
# The sum of the first 3 odd numbers is 9
# No. of iterations (i)        Successive Bisections (half bracket length)
#          0                     2.5
#
#          1                     1.25
#
#          2                     0.625
#
#          3                     0.3125
#
#          4                     0.15625
#
#          5                     0.078125
#
#          6                     0.0390625
#
#          7                     0.01953125
#
#          8                     0.009765625
#
#          9                     0.0048828125
#
#          10                     0.00244140625
#
#          11                     0.001220703125
#
#          12                     0.0006103515625
#
#          13                     0.00030517578125
#
#          14                     0.000152587890625
#
# 1.9999847412109375 is the root.
# The matrix representation is:
#  2   0   0
#
#  0   2   0
#
#  0   0   2
#
# ---
